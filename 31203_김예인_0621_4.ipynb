# %% [markdown]
# # 문제5
# 지하철게임 만들기
#
# > 1. 변수 선언을 정확히 실시하였는가, (5점)
# > 2. 리스트에 지하철 노선을 정확히 입력하였는가. (5점)
# > 3. for문을 정확하게 사용하여 게임을 구현하였는가. (5점)
# > 4. 신분당선, 팔호선 선택을 위한 조건물을 사용하였는가. (5점)
# > 5. 지하철 역 입력에 대한 부분을 정확하게 구현하였는가. (5wja)
# > 6. 각 호선에 맞지 않은 데이터가 입력되었을 경우 틀렸다는 문구가 출력되는가.
# > 7. break문을 사용하여 프로그램이 정확하게 종료되는가.
# > 8. 오탈자 없이 데이터를 정확하게 출력하였는가.
# > 9. 기타 사항은 <출력형태>와 같이 출력되도록 프로그래밍을 실시한다.
#
# ```
# 문제5 : 지하철~♪♬지하철~♪♬지하철~♪♬지하철~♪♬
# 몇호선?! 신분당선
# 신흥
# 땡! 해당 역은 신분당선이 아닙니다!><
# 벌칙 당첨!!
# ```

# %%
신분당선 = ['광교', '광교중앙', '상현', '성복', '수지구청', '동천', '미금', '정자', '판교', '청계산입구', '양재시민의숲', '양재', '강남', '신논현', '노현', '신사']
팔호선 = ['모란', '수진', '신흥', '단대오거리', '남한산성입구', '산성', '남위례', '복정', '장지', '문정', '가락시장', '송파', '석촌', '잠실', '몽촌토성', '강동구청', '천호', '암사']

print('문제5 :','지하철~♪♬'*4)
호선 = input('몇호선?! ')
for i in range(5) :
    if 호선 == '신분당선' :
        입력 = input('역이름 입력 : ')
        if 입력 not in 신분당선 :
            print('땡! 해당 역은 {}이 아닙니다!><'.format(호선))
            print('벌칙 당첨!!')
            break
    if 호선 == '팔호선' :
        입력 = input('역이름 입력 : ')
        if 입력 not in 팔호선 :
            print('땡! 해당 역은 {}이 아닙니다!><'.format(호선))
            print('벌칙 당첨!!')
            break
# Out:
# 문제5 : 지하철~♪♬지하철~♪♬지하철~♪♬지하철~♪♬
# 몇호선?! 팔호선
# 역이름 입력 : 장지
# 역이름 입력 : 단대오거리
# 역이름 입력 : 신흥
# 역이름 입력 : 모란
# 역이름 입력 : 석촌

# %%
신분당선 = ['광교', '광교중앙', '상현', '성복', '수지구청', '동천', '미금', '정자', '판교', '청계산입구', '양재시민의숲', '양재', '강남', '신논현', '노현', '신사']
팔호선 = ['모란', '수진', '신흥', '단대오거리', '남한산성입구', '산성', '남위례', '복정', '장지', '문정', '가락시장', '송파', '석촌', '잠실', '몽촌토성', '강동구청', '천호', '암사']

print('문제5 :', '지하철~'*4)
호선 = input('몇호선?! ')
for i in range(5):
    if 호선 == '신분당선' :
        입력 = input('역이름 입력 : ')
        if 입력 not in 신분당선 :
            print('땡! 해당 역은 {}이 아닙니다!><'.format(호선))
            print('벌칙 당첨')
            break
    if 호선 == '팔호선' :
        입력 = input('역이름 입력 : ')
        if 입력 not in 팔고선 : 
            print('땡! 해당 역은 {}이 아닙니다!><'.format(호선))
            print('벌칙당첨!!')
            break
# Out:
# 문제5 : 지하철~지하철~지하철~지하철~
# 몇호선?! 신분당선
# 역이름 입력 : 판교
# 역이름 입력 : 신논현
# 역이름 입력 : 강남
# 역이름 입력 : 청계산 입ㄹ
# 땡! 해당 역은 신분당선이 아닙니다!><
# 벌칙 당첨
