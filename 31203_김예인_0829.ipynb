# %% [markdown]
# ## 그래프 그리기
# ### 1.1. 데이터 시각화 도구 사용하기
#  - 데이터 시각화 : 데이터를 이해하기 쉽게 시각적으로 표현하는 것<br>
# 모듈, 패키지, 라이브러리
# - 모듈 : 특정 기능이 정의되어 있는 단일파일
# - 패키지 : 여러 모듈을 모아 둔 것
# - 라이브러리 : 모듈과 패키지를 모아둔 것<br>
#   표준 라이브러리 / 외부 라이브러리

# %%
# import  matplotlib.pyplot as plt //matplotlib.pyplot을 plt로 줄여 씀
# as는 명령어를 줄여서 사용할 때 쓰는 명령어

# 꺽은선 그래프 그리기
# 명령어는 plot()

import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[1,5,7,3,7],'g')
plt.title('title')
plt.show()

# %% [markdown]
# ### 2.1. 막대그래프 그리기

# %%
import matplotlib.font_manager as fm

font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]
# Out:
# ['C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\BrushScriptStd.otf',
#  'C:\\Windows\\Fonts\\KozMinPro-ExtraLight.otf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\MyriadPro-CondIt.otf',
#  'C:\\Windows\\Fonts\\MyriadPro-It.otf',
#  'C:\\Windows\\Fonts\\SitkaZ.ttc',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\KozGoPro-Regular.otf',
#  'C:\\Windows\\Fonts\\FZSong_Super.TTF',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  'C:\\Windows\\Fonts\\TektonPro-BoldExt.otf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\OCRAStd.otf',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\MinionPro-MediumIt.otf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\TektonPro-BoldObl.otf',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
# ...

# %%
# import matplotlib
# import matplotlib.font_manager as fm

fm.get_fontconfig_fonts()
font_location =  'C:\\Windows\\Fonts\\malgunbd.ttf' # For Windows
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5],[1,5,7,3,7],'g')
plt.title('월별 판매 현황')
plt.show()
